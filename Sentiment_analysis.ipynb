# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk

# %%
example = "/content/text_38.txt"

# %%
file1 = open(example,"r")

# %%
FileContent = file1.read()

# %%
 nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
tokens = nltk.word_tokenize(FileContent)

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
tagged = nltk.pos_tag(tokens)

# %%
nltk.download('maxent_ne_chunker')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# True

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from nltk.stem import WordNetLemmatizer

# %%
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
lemma = WordNetLemmatizer()
stop_words = stopwords.words('english')

# %%
import re

# %%
def text_prep(x):
     corp = str(x).lower() 
     corp = re.sub('[^a-zA-Z]+',' ', corp).strip() 
     tokens = nltk.word_tokenize(corp)
     words = [t for t in tokens if t not in stop_words]
     lemmatize = [lemma.lemmatize(w) for w in words]
    
     return lemmatize

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
text_prep(FileContent)
# Out:
# ['human',
#  'mind',
#  'fascination',
#  'carrying',
#  'potential',
#  'tinkering',
#  'nature',
#  'pixie',
#  'dust',
#  'intelligence',
#  'creating',
#  'solving',
#  'mystery',
#  'wonder',
#  'anything',
#  'admiration',
#  'however',
#  'matter',
#  'captivating',
#  'human',
#  'mind',
#  'could',
#  'sometimes',
#  'appalled',
#  'could',
#  'hunger',
#  'maybe',
#  'desire',
#  'want',
#  'go',
#  'beyond',
#  'unravel',
#  'limitation',
#  'maybe',
#  'something',
#  'like',
#  'pure',
#  'greed',
#  'human',
#  'never',
#  'stopped',
#  'always',
#  'keep',
#  'evolving',
#  'come',
#  'intelligence',
#  'make',
#  'supreme',
#  'intelligence',
#  'call',
#  'supremacy',
#  'evolve',
#  'something',
#  'opposed',
#  'challenge',
#  'human',
#  'mind',
#  'capability',
#  'making',
#  'question',
#  'importance',
#  'among',
#  'artificial',
#  'intelligence',
#  'came',
#  'revolution',
#  'havoc',
#  'first',
#  'came',
#  'light',
#  'concept',
#  'making',
# ...

# %%
df = pd.DataFrame(text_prep(FileContent))

# %%
df["words"] = pd.DataFrame(text_prep(FileContent))

# %%
df.drop(0,axis=1,inplace = True)

# %%
df.head()
# Out:
#          words
# 0        human
# 1         mind
# 2  fascination
# 3     carrying
# 4    potential

# %%
file2 = open("/content/Negative_word.txt","r")

# %%
file3= open("/content/Positive_words.txt","r")

# %%
neg_words = file2.read().split()
pos_words = file3.read().split()

# %%
num_pos = len([i for i in df["words"] if i in pos_words])

# %%
num_pos
# Out:
# 86

# %%
num_neg = len([i for i in df["words"] if i in neg_words])

# %%
num_neg
# Out:
# 36

# %%
polarity_score = (num_pos-num_neg)/((num_pos+num_neg)+0.000001)
polarity_score
# Out:
# 0.4098360622144585
