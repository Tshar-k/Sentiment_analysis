# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("ggplot")

import nltk

# %%
example = "/content/text_37 (1).txt"

# %%
# reading data
file1 = open(example,"r")

# %%
file1
# Out:
# <_io.TextIOWrapper name='/content/text_37 (1).txt' mode='r' encoding='UTF-8'>

# %%
type(file1)
# Out:
# _io.TextIOWrapper

# %%
FileContent = file1.read()

# %%
FileContent
# Out:
# 'Introduction\n“If anything kills over 10 million people in the next few decades, it will be a highly infectious virus rather than a war. Not missiles but microbes.” Bill Gates’s remarks at a TED conference in 2014, right after the world had avoided the Ebola outbreak. When the new, unprecedented, invisible virus hit us, it met an overwhelmed and unprepared healthcare system and oblivious population. This public health emergency demonstrated our lack of scientific consideration and underlined the alarming need for robust innovations in our health and medical facilities. For the past few years, artificial intelligence has proven to be of tangible potential in the healthcare sectors, clinical practices, translational medical and biomedical research.\nAfter the first case was detected in China on December 31st 2019, it was an AI program developed by BlueDot that alerted the world about the pandemic. It was quick to realise AI’s ability to analyse large chunks of data could help in detec
# ...

# %%
 nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
tokens = nltk.word_tokenize(FileContent)

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
tagged = nltk.pos_tag(tokens)

# %%
nltk.download('maxent_ne_chunker')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# True

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
entity = nltk.chunk.ne_chunk(tagged)
entity.pprint()
# Out:
# (S
#   Introduction/NNP
#   “/NNP
#   If/IN
#   anything/NN
#   kills/VBZ
#   over/IN
#   10/CD
#   million/CD
#   people/NNS
#   in/IN
#   the/DT
#   next/JJ
#   few/JJ
#   decades/NNS
#   ,/,
#   it/PRP
#   will/MD
#   be/VB
#   a/DT
#   highly/RB
#   infectious/JJ
#   virus/NN
#   rather/RB
#   than/IN
#   a/DT
#   war/NN
#   ./.
#   Not/RB
#   missiles/NNS
#   but/CC
#   microbes./JJ
#   ”/NNP
#   (PERSON Bill/NNP Gates/NNP)
#   ’/NNP
#   s/VBD
#   remarks/NNS
#   at/IN
#   a/DT
#   (ORGANIZATION TED/NNP)
#   conference/NN
#   in/IN
#   2014/CD
#   ,/,
#   right/RB
#   after/IN
#   the/DT
#   world/NN
#   had/VBD
#   avoided/VBN
#   the/DT
#   (ORGANIZATION Ebola/NNP)
#   outbreak/NN
#   ./.
#   When/WRB
#   the/DT
#   new/JJ
#   ,/,
#   unprecedented/JJ
#   ,/,
#   invisible/JJ
#   virus/NN
#   hit/VBD
#   us/PRP
#   ,/,
#   it/PRP
#   met/VBD
#   an/DT
#   overwhelmed/JJ
#   and/CC
#   unprepared/JJ
#   healthcare/NN
#   system/NN
#   and/CC
#   oblivious/JJ
#   population/NN
# ...

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# VADER MODEL

# %%
from nltk.sentiment  import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

sia = SentimentIntensityAnalyzer()

# %%
sia

# %%
sia.polarity_scores("i am so happy!")
# Out:
# {'neg': 0.0, 'neu': 0.318, 'pos': 0.682, 'compound': 0.6468}

# %%
sia.polarity_scores("he met an accident")
# Out:
# {'neg': 0.508, 'neu': 0.492, 'pos': 0.0, 'compound': -0.4767}

# %%
sia.polarity_scores("mahatama gandhi is the father of the nation")
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
sia.polarity_scores("This is the worst thing ever")
# Out:
# {'neg': 0.451, 'neu': 0.549, 'pos': 0.0, 'compound': -0.6249}

# %%
# run this polarity score over the whole document

# %%
sia.polarity_scores(FileContent)
# Out:
# {'neg': 0.043, 'neu': 0.823, 'pos': 0.134, 'compound': 0.999}
